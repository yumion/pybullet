# %%
import numpy as np
import cv2
import time
from datetime import datetime  # 時刻を取得
import pybullet as p
import pybullet_data

# %%
'''定数の設定'''
NUM_DIZITIZED = 6  # 各状態の離散値への分割数
discount = 0.99  # 時間割引率
lr = 0.5  # 学習係数
MAX_STEPS = 30  # 1試行のstep数cartpoleは195steps立ち続ければ終わり
NUM_EPISODES = 100000  # 最大試行回数
AREA_THRESH = 80  # 赤色物体面積の閾値．0~100で規格化してある

'''学習するときはFalse，学習済みのモデルを使用するときはTrue'''
# 使うq_tableのファイル名を"trained_q_table.npy"とすること
TEST_MODE = False
'''追加学習するときはTrue'''
ADD_TRAIN_MODE = True

# %%
class Agent:
    '''CartPoleのエージェントクラスです、棒付き台車そのものになります'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q関数の更新'''
        self.brain.update_Q_table(observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''行動の決定'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''エージェントが持つ脳となるクラスです、Q学習を実行します'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # ロボットハンドの取れる行動数(コマンド数)
        if TEST_MODE or ADD_TRAIN_MODE:  # 保存したQ-tableを使用
            self.q_table = np.load('trained_q_table.npy')
        else:  # Qテーブルを作成。行数は状態を分割数^(4変数)にデジタル変換した値、列数は行動数を示す
            self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))

    def bins(self, clip_min, clip_max, num):
        '''観測した状態（連続値）を離散値にデジタル変換する閾値を求める'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''観測したobservation状態を、離散値に変換する'''
        area_sum, area_v = observation
        digitized = [
            np.digitize(area_sum, bins=self.bins(0, 10.0, NUM_DIZITIZED)), #　面積の比率
            np.digitize(area_v, bins=self.bins(-10.0, 10.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)]) #　6進数で表して計算を圧縮
    
    def update_Q_table(self, observation, action, reward, observation_next):
        '''QテーブルをQ学習により更新'''
        state = self.digitize_state(observation)  # 状態を離散化
        state_next = self.digitize_state(observation_next)  # 次の状態を離散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + lr * (reward + discount * Max_Q_next - self.q_table[state, action])
        self.save_Q_table()  # Q-tableを更新するたびに保存

    def save_Q_table(self):
        '''学習したQ-tableを保存'''
        np.save(datetime.today().strftime("%m%d")+'_q_table', self.q_table)

    def load_Q_table(self):  # NoneTypeで読み込んでしまうため使ってない
        '''学習済みのQ-tableを読み込み'''
        np.load('trained_q_table.npy')

    def decide_action(self, observation, episode):
        '''ε-greedy法で徐々に最適行動のみを採用する'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 0,1の行動をランダムに返す
        return action

# %%
class  Environment:
    '''CartPoleを実行する環境のクラスです'''

    def __init__(self):
        self.num_states = 2  # 課題の状態の数(面積と重心(x,y)と、それぞれの変化量で6つ)
        self.num_actions = 4  # ロボットハンドの行動（前進，後退，右旋回，左旋回，握る，離す，止まる）
        self.agent = Agent(self.num_states, self.num_actions)  # 環境内で行動するAgentを生成
        '''pybullet'''
        p.connect(p.GUI)
        p.setAdditionalSearchPath("/home/dl-box/atsushi/github/ros_ws/src/test_car_description/urdf/")
        self.maxForce = 10
        
    def renderPicture(self, height=320, width=320):
        '''bullet側からカメラ画像を取得'''
        base_pos, orn = p.getBasePositionAndOrientation(self.car)
        cam_eye = np.array(base_pos) + [0.1,0,0.2]
        cam_target = np.array(base_pos) + [2,0,0.2]
        cam_upvec = [1,0,1]

        view_matrix = p.computeViewMatrix(
                cameraEyePosition=cam_eye,
                cameraTargetPosition=cam_target,
                cameraUpVector=cam_upvec)

        proj_matrix = p.computeProjectionMatrixFOV(
            fov=60, aspect=float(width)/height,
            nearVal=0.1, farVal=100.0)

        (_, _, rgb, _, mask) = p.getCameraImage(
            width=width, height=height, viewMatrix=view_matrix,
            projectionMatrix=proj_matrix, renderer=p.ER_BULLET_HARDWARE_OPENGL)

        rgb_array = np.array(rgb)
        rgb_array = rgb_array[:,:,:3]
        mask_array = np.array(mask)

        return rgb_array

    def green_detect(self, img):
        '''緑色のマスク'''
        # HSV色空間に変換
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        # 緑色のHSVの値域
        hsv_min = np.array([50, 100, 100])
        hsv_max = np.array([70, 255, 255])
        mask = cv2.inRange(hsv, hsv_min, hsv_max)
        return mask

    def calc_area(self, img):
        '''面積計算'''
        img = self.green_detect(img)
        pix_area = cv2.countNonZero(img)  # ピクセル数
        # パーセントを算出
        h, w = img.shape  # frameの面積
        per = round(100 * float(pix_area) / (w * h), 3)  # 0-100で規格化
        print('GREEN_AREA: ', per)
        return pix_area, per

    def reset(self):
        '''環境を初期化する'''
        print('Environment.reset\n')
        
        #bulletの世界をリセット
        p.resetSimulation()
        
        #フィールドを表示
        p.setGravity(0,0,-10)
        self.planeId = p.loadURDF("plane100.urdf")
        
        #オブジェクトモデルを表示
        self.startPos = [0,0,0]
        self.startOrientation = p.getQuaternionFromEuler([0,0,0])
        self.car = p.loadURDF("test_car.urdf", self.startPos, self.startOrientation)
        
        # ターゲットを表示
        targetX, targetY = np.random.permutation(np.arange(10))[0:2]
        self.targetPos = [targetX, targetY, 0]
        self.target = p.createCollisionShape(
            p.GEOM_CYLINDER, radius=0.2, height=2, collisionFramePosition=self.targetPos)
        p.createMultiBody(0, self.target)

        # 目標の面積, 重心の位置を取得する
        frame = self.renderPicture()
        _, area_sum = self.calc_area(frame)
        area_v = 0

        observation = (area_sum, area_v)
        
        return observation, frame

    def get_env(self, area_sum_before):
        '''環境を認識する'''
        '''カメラで写真をとりOpencv2で面積と重心を取得する'''
        frame = self.renderPicture()
        # 赤色の面積とその変化量, 重心の位置とその変化量を取得する
        _, area_sum = self.calc_area(frame)
        area_v = area_sum - area_sum_before
        # 観測量として返す
        observation = (area_sum, area_v)
        return observation, frame

    def act_env(self, observation, action):
        '''決定したactionに従って、ロボットハンドを動かす'''
        if action == 0:  # 前
            self.go()
        elif action == 1:  # 後
            self.back()
        elif action == 2:  # 右
            self.right()
        elif action == 3:  # 左
            self.left()
        
        for i in range(50):
            p.stepSimulation()
            time.sleep(1./240.)
        
        area_sum, _ = observation
        observation_next, _ = self.get_env(area_sum)
        done = self.is_done(observation_next)
        
        return observation_next, done

    def go(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[20,20,20,20],
                forces=np.ones(4)*self.maxForce)
    def back(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[-20,-20,-20,-20],
                forces=np.ones(4)*self.maxForce)
    def right(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[20,12,20,12],
                forces=np.ones(4)*self.maxForce)
    def left(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[12,20,12,20],
                forces=np.ones(4)*self.maxForce)
    def stop(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[0,0,0,0],
                forces=np.ones(4)*self.maxForce)
    
    def is_done(self, observation):
        '''observationによって終了判定をする'''
        #終了判定は面積が閾値以上&面積の変化なし（重心位置が画像の真ん中？カメラの位置によるけど，とりあえずはなし）
        done = False
        area_sum, area_v = observation
        if area_sum > AREA_THRESH:
            done = True
        return done

    def run(self):
        '''実行'''
        print('Environment.run')
        complete_episodes = 0  # 連続で取り続けた試行数
        is_episode_final = False  # 最終試行フラグ

        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation, frame = self.reset()  # 環境の初期化

            for step in range(MAX_STEPS):  # 1エピソードのループ
                print('Step: {0} of Episode: {1}'.format(step+1, episode))
                # 行動を求める
                action = self.agent.get_action(observation, episode)
                # 行動a_tの実行により、s_{t+1}, r_{t+1}を求める
                observation_next, done = self.act_env(observation, action)

                # 報酬を与える
                if done:
                    reward = 1  # 目標を掴んだら報酬1を与える
                    print ('reward: +1')
                    complete_episodes += 1  # 連続記録を更新
                else:
                    reward = 0  # 途中の報酬は0
                    print ('reward: 0')

                # step+1の状態observation_nextを用いて,Q関数を更新する
                if TEST_MODE:  # 保存したQ-TABLEを使用する
                    continue
                else:
                    self.agent.update_Q_function(observation, action, reward, observation_next)

                # 観測の更新
                observation = observation_next

                # 終了時の処理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(episode, step + 1))
                    break

                # 1episode内でdoneできなかったら罰を与える
                if step == MAX_STEPS-1:
                    reward = -1
                    print('reward: -1')
                    complete_episodes = 0  # 4step以上連続で立ち続けた試行数をリセット

            if is_episode_final is True:  # 最終試行では動画を保存と描画
                Brain(num_states=self.num_states, num_actions=self.num_actions).save_Q_table()  # Q-tableを保存する
                print('finished')
                break

            if complete_episodes >= 10:  # 5連続成功なら
                print('10回連続成功\n次で最終試行')
                is_episode_final = True  # 次の試行を最終試行とする

# %%
robot_hand_env = Environment()
robot_hand_env.run()
# Out:
# Environment.run
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 0
# GREEN_AREA:  3.423
# reward: 0
# Step: 7 of Episode: 0
# GREEN_AREA:  10.306
# reward: 0
# Step: 8 of Episode: 0
# GREEN_AREA:  3.798
# reward: 0
# Step: 9 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode:
of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 4
# GREEN_AREA:  3.175
# reward: 0
# Step: 28 of Episode: 4
# GREEN_AREA:  3.663
# reward: 0
# Step: 29 of Episode: 4
# GREEN_AREA:  3.921
# reward: 0
# Step: 30 of Episode: 4
# GREEN_AREA:  3.928
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 5
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 5
# GREEN_AREA:  3.6
# reward: 0
# Step: 6 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 5
# GREEN_AREA:  0.675
# reward: 0
# Step: 9 of Episode: 5
# GREEN_AREA:  11.774
# reward: 0
# Step: 10 of Episode: 5
# GREEN_AREA:  6.183
# reward: 0
# Step: 11 of Episode: 5
# GREEN_AREA:  5.171
# reward: 0
# Step: 12 of Episode: 5
# GREEN_AREA:  5.123
# reward: 0
# Step: 13 of Episode: 5
# GREEN_AREA:  5.194
# reward: 0
# Step: 14 of Episode: 5
# GREEN_AREA:  1.562
# reward: 0
# Step: 15 of Episode: 5
# GREEN_AREA:  1.287
# reward: 0
# Step: 16 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 5
# GREEN_AREA:  1.28
# reward: 0
# Step: 27 of Episode: 5
# GREEN_AREA:  3.044
# reward: 0
# Step: 28 of Episode: 5
# GREEN_AREA:  4.077
# reward: 0
# Step: 29 of Episode: 5
# GREEN_AREA:  4.042
# reward: 0
# Step: 30 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.394
# Step: 1 of Episode: 6
# GREEN_AREA:  0.406
# reward: 0
# Step: 2 of Episode: 6
# GREEN_AREA:  0.414
# reward: 0
# Step: 3 of Episode: 6
# GREEN_AREA:  0.419
# reward: 0
# Step: 4 of Episode: 6
# GREEN_AREA:  0.474
# reward: 0
# Step: 5 of Episode: 6
# GREEN_AREA:  5.79
# reward: 0
# Step: 6 of Episode: 6
# GREEN_AREA:  8.047
# reward: 0
# Step: 7 of Episode: 6
# GREEN_AREA:  19.446
# reward: 0
# Step: 8 of Episode: 6
# GREEN_AREA:  10.697
# reward: 0
# Step: 9 of Episode: 6
# GREEN_AREA:  19.474
# reward: 0
# Step: 10 of Episode: 6
# GREEN_AREA:  11.06
# reward: 0
# Step: 11 of Episode: 6
# GREEN_AREA:  19.782
# reward: 0
# Step: 12 of Episode: 6
# GREEN_AREA:  11.852
# reward: 0
# Step: 13 of Episode: 6
# GREEN_AREA:  19.952
# reward: 0
# Step: 14 of Episode: 6
# GREEN_AREA:  12.744
# reward: 0
# Step: 15 of Episode: 6
# GREEN_AREA:  20.587
# reward: 0
# Step: 16 of Episode: 6
# GREEN_AREA:  11.718
# reward: 0
# Step: 17 of Episode: 6
# GREEN_AREA:  21.276
# reward: 0
# Step: 18 of Episode: 6
# GREEN_AREA:  11.998
# reward: 0
# Step: 19 of Episode: 6
# GREEN_AREA:  21.636
# reward: 0
# Step: 20 of Episode: 6
# GREEN_AREA:  23.731
# reward: 0
# Step: 21 of Episode: 6
# GREEN_AREA:  24.689
# reward: 0
# Step: 22 of Episode: 6
# GREEN_AREA:  22.291
# reward: 0
# Step: 23 of Episode: 6
# GREEN_AREA:  14.943
# reward: 0
# Step: 24 of Episode: 6
# GREEN_AREA:  18.748
# reward: 0
# Step: 25 of Episode: 6
# GREEN_AREA:  23.792
# reward: 0
# Step: 26 of Episode: 6
# GREEN_AREA:  26.409
# reward: 0
# Step: 27 of Episode: 6
# GREEN_AREA:  9.714
# reward: 0
# Step: 28 of Episode: 6
# GREEN_AREA:  13.879
# reward: 0
# Step: 29 of Episode: 6
# GREEN_AREA:  2.329
# reward: 0
# Step: 30 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 7
# GREEN_AREA:  5.028
# reward: 0
# Step: 6 of Episode: 7
# GREEN_AREA:  6.504
# reward: 0
# Step: 7 of Episode: 7
# GREEN_AREA:  1.479
# reward: 0
# Step: 8 of Episode: 7
# GREEN_AREA:  0.935
# reward: 0
# Step: 9 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 7
# GREEN_AREA:  0.442
# reward: 0
# Step: 25 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  9.039
# Step: 1 of Episode: 9
# GREEN_AREA:  9.575
# reward: 0
# Step: 2 of Episode: 9
# GREEN_AREA:  11.661
# reward: 0
# Step: 3 of Episode: 9
# GREEN_AREA:  14.696
# reward: 0
# Step: 4 of Episode: 9
# GREEN_AREA:  21.778
# reward: 0
# Step: 5 of Episode: 9
# GREEN_AREA:  29.365
# reward: 0
# Step: 6 of Episode: 9
# GREEN_AREA:  61.07
# reward: 0
# Step: 7 of Episode: 9
# GREEN_AREA:  100.0
# reward: +1
# 9 Episode: Finished after 7 time steps
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.489
# Step: 1 of Episode: 12
# GREEN_AREA:  0.488
# reward: 0
# Step: 2 of Episode: 12
# GREEN_AREA:  0.535
# reward: 0
# Step: 3 of Episode: 12
# GREEN_AREA:  0.504
# reward: 0
# Step: 4 of Episode: 12
# GREEN_AREA:  0.557
# reward: 0
# Step: 5 of Episode: 12
# GREEN_AREA:  0.62
# reward: 0
# Step: 6 of Episode: 12
# GREEN_AREA:  0.692
# reward: 0
# Step: 7 of Episode: 12
# GREEN_AREA:  0.789
# reward: 0
# Step: 8 of Episode: 12
# GREEN_AREA:  0.87
# reward: 0
# Step: 9 of Episode: 12
# GREEN_AREA:  0.927
# reward: 0
# Step: 10 of Episode: 12
# GREEN_AREA:  1.096
# reward: 0
# Step: 11 of Episode: 12
# GREEN_AREA:  1.312
# reward: 0
# Step: 12 of Episode: 12
# GREEN_AREA:  1.566
# reward: 0
# Step: 13 of Episode: 12
# GREEN_AREA:  1.89
# reward: 0
# Step: 14 of Episode: 12
# GREEN_AREA:  2.339
# reward: 0
# Step: 15 of Episode: 12
# GREEN_AREA:  2.974
# reward: 0
# Step: 16 of Episode: 12
# GREEN_AREA:  4.009
# reward: 0
# Step: 17 of Episode: 12
# GREEN_AREA:  5.541
# reward: 0
# Step: 18 of Episode: 12
# GREEN_AREA:  6.817
# reward: 0
# Step: 19 of Episode: 12
# GREEN_AREA:  3.784
# reward: 0
# Step: 20 of Episode: 12
# GREEN_AREA:  0.53
# reward: 0
# Step: 21 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 14
# GREEN_AREA:  1.483
# reward: 0
# Step: 30 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode:
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 24
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 24
# GREEN_AREA:  3.6
# reward: 0
# Step: 6 of Episode: 24
# GREEN_AREA:  3.679
# reward: 0
# Step: 7 of Episode: 24
# GREEN_AREA:  3.659
# reward: 0
# Step: 8 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 24
# GREEN_AREA:  5.013
# reward: 0
# Step: 13 of Episode: 24
# GREEN_AREA:  6.351
# reward: 0
# Step: 14 of Episode: 24
# GREEN_AREA:  2.028
# reward: 0
# Step: 15 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 24
# GREEN_AREA:  3.08
# reward: 0
# Step: 19 of Episode: 24
# GREEN_AREA:  4.138
# reward: 0
# Step: 20 of Episode: 24
# GREEN_AREA:  4.141
# reward: 0
# Step: 21 of Episode: 24
# GREEN_AREA:  4.131
# reward: 0
# Step: 22 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 24
# GREEN_AREA:  4.233
# reward: 0
# Step: 25 of Episode: 24
# GREEN_AREA:  4.723
# reward: 0
# Step: 26 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 24
# GREEN_AREA:  3.418
# reward: 0
# Step: 30 of Episode: 24
# GREEN_AREA:  2.527
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 25
# GREEN_AREA:  2.473
# reward: 0
# Step: 5 of Episode: 25
# GREEN_AREA:  3.122
# reward: 0
# Step: 6 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 25
# GREEN_AREA:  3.144
# reward: 0
# Step: 10 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 25
# GREEN_AREA:  3.805
# reward: 0
# Step: 14 of Episode: 25
# GREEN_AREA:  3.055
# reward: 0
# Step: 15 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 25
# GREEN_AREA:  1.151
# reward: 0
# Step: 19 of Episode: 25
# GREEN_AREA:  11.115
# reward: 0
# Step: 20 of Episode: 25
# GREEN_AREA:  4.656
# reward: 0
# Step: 21 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 25
# GREEN_AREA:  3.888
# reward: 0
# Step: 25 of Episode: 25
# GREEN_AREA:  2.192
# reward: 0
# Step: 26 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 25
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 25
# GREEN_AREA:  0.193
# reward: 0
# Step: 30 of Episode: 25
# GREEN_AREA:  9.142
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 26
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 26
# GREEN_AREA:  3.6
# reward: 0
# Step: 6 of Episode: 26
# GREEN_AREA:  3.679
# reward: 0
# Step: 7 of Episode: 26
# GREEN_AREA:  3.659
# reward: 0
# Step: 8 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 26
# GREEN_AREA:  5.013
# reward: 0
# Step: 13 of Episode: 26
# GREEN_AREA:  6.351
# reward: 0
# Step: 14 of Episode: 26
# GREEN_AREA:  2.028
# reward: 0
# Step: 15 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 26
# GREEN_AREA:  3.092
# reward: 0
# Step: 20 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 26
# GREEN_AREA:  3.045
# reward: 0
# Step: 24 of Episode: 26
# GREEN_AREA:  4.394
# reward: 0
# Step: 25 of Episode: 26
# GREEN_AREA:  4.407
# reward: 0
# Step: 26 of Episode: 26
# GREEN_AREA:  4.336
# reward: 0
# Step: 27 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 26
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 26
# GREEN_AREA:  1.434
# reward: 0
# Step: 30 of Episode: 26
# GREEN_AREA:  12.52
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  2.101
# Step: 1 of Episode: 27
# GREEN_AREA:  2.181
# reward: 0
# Step: 2 of Episode: 27
# GREEN_AREA:  2.373
# reward: 0
# Step: 3 of Episode: 27
# GREEN_AREA:  2.812
# reward: 0
# Step: 4 of Episode: 27
# GREEN_AREA:  3.476
# reward: 0
# Step: 5 of Episode: 27
# GREEN_AREA:  4.525
# reward: 0
# Step: 6 of Episode: 27
# GREEN_AREA:  6.622
# reward: 0
# Step: 7 of Episode: 27
# GREEN_AREA:  3.786
# reward: 0
# Step: 8 of Episode: 27
# GREEN_AREA:  0.536
# reward: 0
# Step: 9 of Episode: 27
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 27
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 27
# GREEN_AREA:  0.122
# reward: 0
# Step: 12 of Episode: 27
# GREEN_AREA:  5.71
# reward: 0
# Step: 13 of Episode: 27
# GREEN_AREA:  7.283
# reward: 0
# Step: 14 of Episode: 27
# GREEN_AREA:  15.937
# reward: 0
# Step: 15 of Episode: 27
# GREEN_AREA:  8.54
# reward: 0
# Step: 16 of Episode: 27
# GREEN_AREA:  16.435
# reward: 0
# Step: 17 of Episode: 27
# GREEN_AREA:  8.395
# reward: 0
# Step: 18 of Episode: 27
# GREEN_AREA:  16.179
# reward: 0
# Step: 19 of Episode: 27
# GREEN_AREA:  9.596
# reward: 0
# Step: 20 of Episode: 27
# GREEN_AREA:  7.887
# reward: 0
# Step: 21 of Episode: 27
# GREEN_AREA:  7.925
# reward: 0
# Step: 22 of Episode: 27
# GREEN_AREA:  13.782
# reward: 0
# Step: 23 of Episode: 27
# GREEN_AREA:  17.425
# reward: 0
# Step: 24 of Episode: 27
# GREEN_AREA:  12.542
# reward: 0
# Step: 25 of Episode: 27
# GREEN_AREA:  0.016
# reward: 0
# Step: 26 of Episode: 27
# GREEN_AREA:  2.061
# reward: 0
# Step: 27 of Episode: 27
# GREEN_AREA:  1.807
# reward: 0
# Step: 28 of Episode: 27
# GREEN_AREA:  0.978
# reward: 0
# Step: 29 of Episode: 27
# GREEN_AREA:  0.412
# reward: 0
# Step: 30 of Episode: 27
# GREEN_AREA:  1.538
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 28
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 28
# GREEN_AREA:  3.6
# reward: 0
# Step: 6 of Episode: 28
# GREEN_AREA:  3.679
# reward: 0
# Step: 7 of Episode: 28
# GREEN_AREA:  3.659
# reward: 0
# Step: 8 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 28
# GREEN_AREA:  5.013
# reward: 0
# Step: 13 of Episode: 28
# GREEN_AREA:  6.351
# reward: 0
# Step: 14 of Episode: 28
# GREEN_AREA:  2.028
# reward: 0
# Step: 15 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 28
# GREEN_AREA:  2.977
# reward: 0
# Step: 20 of Episode: 28
# GREEN_AREA:  4.261
# reward: 0
# Step: 21 of Episode: 28
# GREEN_AREA:  4.206
# reward: 0
# Step: 22 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 28
# GREEN_AREA:  0.744
# reward: 0
# Step: 25 of Episode: 28
# GREEN_AREA:  11.024
# reward: 0
# Step: 26 of Episode: 28
# GREEN_AREA:  5.081
# reward: 0
# Step: 27 of Episode: 28
# GREEN_AREA:  4.08
# reward: 0
# Step: 28 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 28
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  7.026
# Step: 1 of Episode: 29
# GREEN_AREA:  6.71
# reward: 0
# Step: 2 of Episode: 29
# GREEN_AREA:  5.394
# reward: 0
# Step: 3 of Episode: 29
# GREEN_AREA:  1.844
# reward: 0
# Step: 4 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 29
# GREEN_AREA:  2.957
# reward: 0
# Step: 10 of Episode: 29
# GREEN_AREA:  4.014
# reward: 0
# Step: 11 of Episode: 29
# GREEN_AREA:  3.987
# reward: 0
# Step: 12 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 29
# GREEN_AREA:  1.366
# reward: 0
# Step: 15 of Episode: 29
# GREEN_AREA:  13.749
# reward: 0
# Step: 16 of Episode: 29
# GREEN_AREA:  8.057
# reward: 0
# Step: 17 of Episode: 29
# GREEN_AREA:  6.288
# reward: 0
# Step: 18 of Episode: 29
# GREEN_AREA:  6.291
# reward: 0
# Step: 19 of Episode: 29
# GREEN_AREA:  6.287
# reward: 0
# Step: 20 of Episode: 29
# GREEN_AREA:  6.278
# reward: 0
# Step: 21 of Episode: 29
# GREEN_AREA:  6.224
# reward: 0
# Step: 22 of Episode: 29
# GREEN_AREA:  6.198
# reward: 0
# Step: 23 of Episode: 29
# GREEN_AREA:  6.185
# reward: 0
# Step: 24 of Episode: 29
# GREEN_AREA:  6.185
# reward: 0
# Step: 25 of Episode: 29
# GREEN_AREA:  3.215
# reward: 0
# Step: 26 of Episode: 29
# GREEN_AREA:  2.778
# reward: 0
# Step: 27 of Episode: 29
# GREEN_AREA:  2.826
# reward: 0
# Step: 28 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 29
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 30
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 30
# GREEN_AREA:  3.69
# reward: 0
# Step: 12 of Episode: 30
# GREEN_AREA:  4.331
# reward: 0
# Step: 13 of Episode: 30
# GREEN_AREA:  4.329
# reward: 0
# Step: 14 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 30
# GREEN_AREA:  4.353
# reward: 0
# Step: 19 of Episode: 30
# GREEN_AREA:  2.53
# reward: 0
# Step: 20 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 30
# GREEN_AREA:  0.27
# reward: 0
# Step: 23 of Episode: 30
# GREEN_AREA:  9.185
# reward: 0
# Step: 24 of Episode: 30
# GREEN_AREA:  3.73
# reward: 0
# Step: 25 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 30
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 31
# GREEN_AREA:  1.679
# reward: 0
# Step: 5 of Episode: 31
# GREEN_AREA:  2.721
# reward: 0
# Step: 6 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 31
# GREEN_AREA:  3.489
# reward: 0
# Step: 9 of Episode: 31
# GREEN_AREA:  5.397
# reward: 0
# Step: 10 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 31
# GREEN_AREA:  8.533
# reward: 0
# Step: 14 of Episode: 31
# GREEN_AREA:  3.839
# reward: 0
# Step: 15 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 31
# GREEN_AREA:  0.085
# reward: 0
# Step: 18 of Episode: 31
# GREEN_AREA:  11.547
# reward: 0
# Step: 19 of Episode: 31
# GREEN_AREA:  6.161
# reward: 0
# Step: 20 of Episode: 31
# GREEN_AREA:  5.013
# reward: 0
# Step: 21 of Episode: 31
# GREEN_AREA:  5.09
# reward: 0
# Step: 22 of Episode: 31
# GREEN_AREA:  0.639
# reward: 0
# Step: 23 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 31
# GREEN_AREA:  0.0
# reward: 0
# ...
# reward: 0
# Step: 18 of Episode: 59
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 59
# GREEN_AREA:  5.812
# reward: 0
# Step: 20 of Episode: 59
# GREEN_AREA:  7.331
# reward: 0
# Step: 21 of Episode: 59
# GREEN_AREA:  13.676
# reward: 0
# Step: 22 of Episode: 59
# GREEN_AREA:  17.456
# reward: 0
# Step: 23 of Episode: 59
# GREEN_AREA:  13.253
# reward: 0
# Step: 24 of Episode: 59
# GREEN_AREA:  8.374
# reward: 0
# Step: 25 of Episode: 59
# GREEN_AREA:  6.427
# reward: 0
# Step: 26 of Episode: 59
# GREEN_AREA:  6.427
# reward: 0
# Step: 27 of Episode: 59
# GREEN_AREA:  11.001
# reward: 0
# Step: 28 of Episode: 59
# GREEN_AREA:  8.766
# reward: 0
# Step: 29 of Episode: 59
# GREEN_AREA:  2.665
# reward: 0
# Step: 30 of Episode: 59
# GREEN_AREA:  4.261
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.394
# Step: 1 of Episode: 60
# GREEN_AREA:  0.406
# reward: 0
# Step: 2 of Episode: 60
# GREEN_AREA:  0.414
# reward: 0
# Step: 3 of Episode: 60
# GREEN_AREA:  0.419
# reward: 0
# Step: 4 of Episode: 60
# GREEN_AREA:  2.846
# reward: 0
# Step: 5 of Episode: 60
# GREEN_AREA:  0.522
# reward: 0
# Step: 6 of Episode: 60
# GREEN_AREA:  0.552
# reward: 0
# Step: 7 of Episode: 60
# GREEN_AREA:  0.605
# reward: 0
# Step: 8 of Episode: 60
# GREEN_AREA:  0.624
# reward: 0
# Step: 9 of Episode: 60
# GREEN_AREA:  5.02
# reward: 0
# Step: 10 of Episode: 60
# GREEN_AREA:  6.565
# reward: 0
# Step: 11 of Episode: 60
# GREEN_AREA:  1.336
# reward: 0
# Step: 12 of Episode: 60
# GREEN_AREA:  1.141
# reward: 0
# Step: 13 of Episode: 60
# GREEN_AREA:  1.164
# reward: 0
# Step: 14 of Episode: 60
# GREEN_AREA:  2.609
# reward: 0
# Step: 15 of Episode: 60
# GREEN_AREA:  3.815
# reward: 0
# Step: 16 of Episode: 60
# GREEN_AREA:  4.232
# reward: 0
# Step: 17 of Episode: 60
# GREEN_AREA:  4.741
# reward: 0
# Step: 18 of Episode: 60
# GREEN_AREA:  4.938
# reward: 0
# Step: 19 of Episode: 60
# GREEN_AREA:  3.643
# reward: 0
# Step: 20 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 60
# GREEN_AREA:  2.446
# reward: 0
# Step: 25 of Episode: 60
# GREEN_AREA:  10.645
# reward: 0
# Step: 26 of Episode: 60
# GREEN_AREA:  2.284
# reward: 0
# Step: 27 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 60
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 61
# GREEN_AREA:  0.782
# reward: 0
# Step: 23 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 61
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.333
# Step: 1 of Episode: 62
# GREEN_AREA:  0.372
# reward: 0
# Step: 2 of Episode: 62
# GREEN_AREA:  0.401
# reward: 0
# Step: 3 of Episode: 62
# GREEN_AREA:  0.402
# reward: 0
# Step: 4 of Episode: 62
# GREEN_AREA:  0.312
# reward: 0
# Step: 5 of Episode: 62
# GREEN_AREA:  0.25
# reward: 0
# Step: 6 of Episode: 62
# GREEN_AREA:  0.16
# reward: 0
# Step: 7 of Episode: 62
# GREEN_AREA:  0.064
# reward: 0
# Step: 8 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 62
# GREEN_AREA:  4.307
# reward: 0
# Step: 13 of Episode: 62
# GREEN_AREA:  2.211
# reward: 0
# Step: 14 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 62
# GREEN_AREA:  0.787
# reward: 0
# Step: 18 of Episode: 62
# GREEN_AREA:  9.938
# reward: 0
# Step: 19 of Episode: 62
# GREEN_AREA:  3.043
# reward: 0
# Step: 20 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 62
# GREEN_AREA:  1.362
# reward: 0
# Step: 23 of Episode: 62
# GREEN_AREA:  9.155
# reward: 0
# Step: 24 of Episode: 62
# GREEN_AREA:  2.15
# reward: 0
# Step: 25 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 62
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 62
# GREEN_AREA:  6.065
# reward: 0
# Step: 29 of Episode: 62
# GREEN_AREA:  7.822
# reward: 0
# Step: 30 of Episode: 62
# GREEN_AREA:  18.83
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 63
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 63
# GREEN_AREA:  3.6
# reward: 0
# Step: 6 of Episode: 63
# GREEN_AREA:  3.679
# reward: 0
# Step: 7 of Episode: 63
# GREEN_AREA:  3.659
# reward: 0
# Step: 8 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 63
# GREEN_AREA:  0.759
# reward: 0
# Step: 11 of Episode: 63
# GREEN_AREA:  11.399
# reward: 0
# Step: 12 of Episode: 63
# GREEN_AREA:  5.193
# reward: 0
# Step: 13 of Episode: 63
# GREEN_AREA:  3.617
# reward: 0
# Step: 14 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 63
# GREEN_AREA:  4.482
# reward: 0
# Step: 19 of Episode: 63
# GREEN_AREA:  2.374
# reward: 0
# Step: 20 of Episode: 63
# GREEN_AREA:  0.507
# reward: 0
# Step: 21 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 63
# GREEN_AREA:  2.005
# reward: 0
# Step: 25 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 63
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 63
# GREEN_AREA:  0.039
# reward: 0
# Step: 28 of Episode: 63
# GREEN_AREA:  7.457
# reward: 0
# Step: 29 of Episode: 63
# GREEN_AREA:  9.091
# reward: 0
# Step: 30 of Episode: 63
# GREEN_AREA:  16.248
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 64
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 64
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 64
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 64
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 64
# GREEN_AREA:  12.823
# reward: 0
# Step: 6 of Episode: 64
# GREEN_AREA:  5.25
# reward: 0
# Step: 7 of Episode: 64
# GREEN_AREA:  13.26
# reward: 0
# Step: 8 of Episode: 64
# GREEN_AREA:  6.678
# reward: 0
# Step: 9 of Episode: 64
# GREEN_AREA:  4.786
# reward: 0
# Step: 10 of Episode: 64
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 64
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 64
# GREEN_AREA:  1.285
# reward: 0
# Step: 13 of Episode: 64
# GREEN_AREA:  12.399
# reward: 0
# Step: 14 of Episode: 64
# GREEN_AREA:  5.361
# reward: 0
# Step: 15 of Episode: 64
# GREEN_AREA:  12.106
# reward: 0
# Step: 16 of Episode: 64
# GREEN_AREA:  5.212
# reward: 0
# Step: 17 of Episode: 64
# GREEN_AREA:  11.333
# reward: 0
# Step: 18 of Episode: 64
# GREEN_AREA:  18.444
# reward: 0
# Step: 19 of Episode: 64
# GREEN_AREA:  17.368
# reward: 0
# Step: 20 of Episode: 64
# GREEN_AREA:  14.131
# reward: 0
# Step: 21 of Episode: 64
# GREEN_AREA:  14.16
# reward: 0
# Step: 22 of Episode: 64
# GREEN_AREA:  18.612
# reward: 0
# Step: 23 of Episode: 64
# GREEN_AREA:  16.9
# reward: 0
# Step: 24 of Episode: 64
# GREEN_AREA:  16.004
# reward: 0
# Step: 25 of Episode: 64
# GREEN_AREA:  16.153
# reward: 0
# Step: 26 of Episode: 64
# GREEN_AREA:  14.816
# reward: 0
# Step: 27 of Episode: 64
# GREEN_AREA:  14.541
# reward: 0
# Step: 28 of Episode: 64
# GREEN_AREA:  14.554
# reward: 0
# Step: 29 of Episode: 64
# GREEN_AREA:  13.346
# reward: 0
# Step: 30 of Episode: 64
# GREEN_AREA:  13.079
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 65
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 65
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 65
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 65
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 65
# GREEN_AREA:  12.823
# reward: 0
# Step: 6 of Episode: 65
# GREEN_AREA:  17.733
# reward: 0
# Step: 7 of Episode: 65
# GREEN_AREA:  14.546
# reward: 0
# Step: 8 of Episode: 65
# GREEN_AREA:  10.881
# reward: 0
# Step: 9 of Episode: 65
# GREEN_AREA:  10.305
# reward: 0
# Step: 10 of Episode: 65
# GREEN_AREA:  10.323
# reward: 0
# Step: 11 of Episode: 65
# GREEN_AREA:  3.671
# reward: 0
# Step: 12 of Episode: 65
# GREEN_AREA:  10.492
# reward: 0
# Step: 13 of Episode: 65
# GREEN_AREA:  15.185
# reward: 0
# Step: 14 of Episode: 65
# GREEN_AREA:  14.635
# reward: 0
# Step: 15 of Episode: 65
# GREEN_AREA:  12.371
# reward: 0
# Step: 16 of Episode: 65
# GREEN_AREA:  12.531
# reward: 0
# Step: 17 of Episode: 65
# GREEN_AREA:  9.917
# reward: 0
# Step: 18 of Episode: 65
# GREEN_AREA:  4.652
# reward: 0
# Step: 19 of Episode: 65
# GREEN_AREA:  10.536
# reward: 0
# Step: 20 of Episode: 65
# GREEN_AREA:  2.674
# reward: 0
# Step: 21 of Episode: 65
# GREEN_AREA:  0.31
# reward: 0
# Step: 22 of Episode: 65
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 65
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 65
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 65
# GREEN_AREA:  0.588
# reward: 0
# Step: 26 of Episode: 65
# GREEN_AREA:  1.817
# reward: 0
# Step: 27 of Episode: 65
# GREEN_AREA:  0.765
# reward: 0
# Step: 28 of Episode: 65
# GREEN_AREA:  0.458
# reward: 0
# Step: 29 of Episode: 65
# GREEN_AREA:  0.626
# reward: 0
# Step: 30 of Episode: 65
# GREEN_AREA:  0.066
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 66
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 66
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 66
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 66
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 66
# GREEN_AREA:  12.823
# reward: 0
# Step: 6 of Episode: 66
# GREEN_AREA:  17.733
# reward: 0
# Step: 7 of Episode: 66
# GREEN_AREA:  14.546
# reward: 0
# Step: 8 of Episode: 66
# GREEN_AREA:  10.881
# reward: 0
# Step: 9 of Episode: 66
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 66
# GREEN_AREA:  1.565
# reward: 0
# Step: 11 of Episode: 66
# GREEN_AREA:  2.041
# reward: 0
# Step: 12 of Episode: 66
# GREEN_AREA:  2.021
# reward: 0
# Step: 13 of Episode: 66
# GREEN_AREA:  1.958
# reward: 0
# Step: 14 of Episode: 66
# GREEN_AREA:  0.723
# reward: 0
# Step: 15 of Episode: 66
# GREEN_AREA:  1.833
# reward: 0
# Step: 16 of Episode: 66
# GREEN_AREA:  1.964
# reward: 0
# Step: 17 of Episode: 66
# GREEN_AREA:  1.531
# reward: 0
# Step: 18 of Episode: 66
# GREEN_AREA:  1.961
# reward: 0
# Step: 19 of Episode: 66
# GREEN_AREA:  1.845
# reward: 0
# Step: 20 of Episode: 66
# GREEN_AREA:  1.763
# reward: 0
# Step: 21 of Episode: 66
# GREEN_AREA:  1.762
# reward: 0
# Step: 22 of Episode: 66
# GREEN_AREA:  1.642
# reward: 0
# Step: 23 of Episode: 66
# GREEN_AREA:  2.046
# reward: 0
# Step: 24 of Episode: 66
# GREEN_AREA:  1.925
# reward: 0
# Step: 25 of Episode: 66
# GREEN_AREA:  1.91
# reward: 0
# Step: 26 of Episode: 66
# GREEN_AREA:  1.92
# reward: 0
# Step: 27 of Episode: 66
# GREEN_AREA:  1.417
# reward: 0
# Step: 28 of Episode: 66
# GREEN_AREA:  0.172
# reward: 0
# Step: 29 of Episode: 66
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 66
# GREEN_AREA:  0.001
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 67
# GREEN_AREA:  2.375
# reward: 0
# Step: 5 of Episode: 67
# GREEN_AREA:  12.823
# reward: 0
# Step: 6 of Episode: 67
# GREEN_AREA:  5.25
# reward: 0
# Step: 7 of Episode: 67
# GREEN_AREA:  13.26
# reward: 0
# Step: 8 of Episode: 67
# GREEN_AREA:  6.678
# reward: 0
# Step: 9 of Episode: 67
# GREEN_AREA:  4.786
# reward: 0
# Step: 10 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 67
# GREEN_AREA:  4.746
# reward: 0
# Step: 15 of Episode: 67
# GREEN_AREA:  2.119
# reward: 0
# Step: 16 of Episode: 67
# GREEN_AREA:  0.29
# reward: 0
# Step: 17 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 67
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 67
# GREEN_AREA:  0.567
# reward: 0
# Step: 22 of Episode: 67
# GREEN_AREA:  7.141
# reward: 0
# Step: 23 of Episode: 67
# GREEN_AREA:  8.512
# reward: 0
# Step: 24 of Episode: 67
# GREEN_AREA:  16.472
# reward: 0
# Step: 25 of Episode: 67
# GREEN_AREA:  10.358
# reward: 0
# Step: 26 of Episode: 67
# GREEN_AREA:  9.389
# reward: 0
# Step: 27 of Episode: 67
# GREEN_AREA:  9.354
# reward: 0
# Step: 28 of Episode: 67
# GREEN_AREA:  9.42
# reward: 0
# Step: 29 of Episode: 67
# GREEN_AREA:  13.907
# reward: 0
# Step: 30 of Episode: 67
# GREEN_AREA:  18.154
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.679
# Step: 1 of Episode: 68
# GREEN_AREA:  0.677
# reward: 0
# Step: 2 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 3 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 4 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 5 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 6 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 7 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 8 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 9 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 10 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 11 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 12 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 13 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 14 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 15 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 16 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 17 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 18 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 19 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 20 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 21 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 22 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 23 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 24 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 25 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 26 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 27 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 28 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 29 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# Step: 30 of Episode: 68
# GREEN_AREA:  0.679
# reward: 0
# reward: -1
# Environment.reset
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-5859dbcee31f> in <module>
#       1 robot_hand_env = Environment()
# ----> 2 robot_hand_env.run()
#
# <ipython-input-5-4a8b368a9b86> in run(self)
#     163
#     164         for episode in range(NUM_EPISODES):  # 試行数分繰り返す
# --> 165             observation, frame = self.reset()  # 環境の初期化
#     166
#     167             for step in range(MAX_STEPS):  # 1エピソードのループ
#
# <ipython-input-5-4a8b368a9b86> in reset(self)
#      66         #フィールドを表示
#      67         p.setGravity(0,0,-10)
# ---> 68         self.planeId = p.loadURDF("plane100.urdf")
#      69
#      70         #オブジェクトモデルを表示
#
# error: Cannot load URDF file.
