# %%
import numpy as np
import cv2
import time
from datetime import datetime  # 時刻を取得
import pybullet as p
import pybullet_data

# %%
'''定数の設定'''
NUM_DIZITIZED = 6  # 各状態の離散値への分割数
discount = 0.99  # 時間割引率
lr = 0.5  # 学習係数
MAX_STEPS = 30  # 1試行のstep数cartpoleは195steps立ち続ければ終わり
NUM_EPISODES = 100000  # 最大試行回数
AREA_THRESH = 80  # 赤色物体面積の閾値．0~100で規格化してある

'''学習するときはFalse，学習済みのモデルを使用するときはTrue'''
# 使うq_tableのファイル名を"trained_q_table.npy"とすること
TEST_MODE = False
'''追加学習するときはTrue'''
ADD_TRAIN_MODE = True

# %%
class Agent:
    '''CartPoleのエージェントクラスです、棒付き台車そのものになります'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q関数の更新'''
        self.brain.update_Q_table(observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''行動の決定'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''エージェントが持つ脳となるクラスです、Q学習を実行します'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # ロボットハンドの取れる行動数(コマンド数)
        if TEST_MODE or ADD_TRAIN_MODE:  # 保存したQ-tableを使用
            self.q_table = np.load('trained_q_table.npy')
        else:  # Qテーブルを作成。行数は状態を分割数^(4変数)にデジタル変換した値、列数は行動数を示す
            self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))

    def bins(self, clip_min, clip_max, num):
        '''観測した状態（連続値）を離散値にデジタル変換する閾値を求める'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''観測したobservation状態を、離散値に変換する'''
        area_sum, area_v = observation
        digitized = [
            np.digitize(area_sum, bins=self.bins(0, 10.0, NUM_DIZITIZED)), #　面積の比率
            np.digitize(area_v, bins=self.bins(-10.0, 10.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)]) #　6進数で表して計算を圧縮
    
    def update_Q_table(self, observation, action, reward, observation_next):
        '''QテーブルをQ学習により更新'''
        state = self.digitize_state(observation)  # 状態を離散化
        state_next = self.digitize_state(observation_next)  # 次の状態を離散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + lr * (reward + discount * Max_Q_next - self.q_table[state, action])
        self.save_Q_table()  # Q-tableを更新するたびに保存

    def save_Q_table(self):
        '''学習したQ-tableを保存'''
        np.save(datetime.today().strftime("%m%d")+'_q_table', self.q_table)

    def load_Q_table(self):  # NoneTypeで読み込んでしまうため使ってない
        '''学習済みのQ-tableを読み込み'''
        np.load('trained_q_table.npy')

    def decide_action(self, observation, episode):
        '''ε-greedy法で徐々に最適行動のみを採用する'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 0,1の行動をランダムに返す
        return action

# %%
class  Environment:
    '''CartPoleを実行する環境のクラスです'''

    def __init__(self):
        self.num_states = 2  # 課題の状態の数(面積と重心(x,y)と、それぞれの変化量で6つ)
        self.num_actions = 4  # ロボットハンドの行動（前進，後退，右旋回，左旋回，握る，離す，止まる）
        self.agent = Agent(self.num_states, self.num_actions)  # 環境内で行動するAgentを生成
        '''pybullet'''
        p.connect(p.GUI)
        self.maxForce = 10
        
    def renderPicture(self, height=320, width=320):
        '''bullet側からカメラ画像を取得'''
        base_pos, orn = p.getBasePositionAndOrientation(self.car)
        cam_eye = np.array(base_pos) + [0.1,0,0.2]
        cam_target = np.array(base_pos) + [2,0,0.2]
        cam_upvec = [1,0,1]

        view_matrix = p.computeViewMatrix(
                cameraEyePosition=cam_eye,
                cameraTargetPosition=cam_target,
                cameraUpVector=cam_upvec)

        proj_matrix = p.computeProjectionMatrixFOV(
            fov=60, aspect=float(width)/height,
            nearVal=0.1, farVal=100.0)

        (_, _, rgb, _, mask) = p.getCameraImage(
            width=width, height=height, viewMatrix=view_matrix,
            projectionMatrix=proj_matrix, renderer=p.ER_BULLET_HARDWARE_OPENGL)

        rgb_array = np.array(rgb)
        rgb_array = rgb_array[:,:,:3]
        mask_array = np.array(mask)

        return rgb_array

    def green_detect(self, img):
        '''緑色のマスク'''
        # HSV色空間に変換
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        # 緑色のHSVの値域
        hsv_min = np.array([50, 100, 100])
        hsv_max = np.array([70, 255, 255])
        mask = cv2.inRange(hsv, hsv_min, hsv_max)
        return mask

    def calc_area(self, img):
        '''面積計算'''
        img = self.green_detect(img)
        pix_area = cv2.countNonZero(img)  # ピクセル数
        # パーセントを算出
        h, w = img.shape  # frameの面積
        per = round(100 * float(pix_area) / (w * h), 3)  # 0-100で規格化
        print('GREEN_AREA: ', per)
        return pix_area, per

    def reset(self):
        '''環境を初期化する'''
        print('Environment.reset\n')
        
        #bulletの世界をリセット
        p.resetSimulation()
        
        #フィールドを表示
        p.setAdditionalSearchPath(pybullet_data.getDataPath())
        p.setGravity(0,0,-10)
        self.planeId = p.loadURDF("plane.urdf")
        
        #オブジェクトモデルを表示
        p.setAdditionalSearchPath("/home/dl-box/atsushi/github/onodera-lab/ros_ws/src/test_car_description/urdf/")
        self.startPos = [0,0,0]
        self.startOrientation = p.getQuaternionFromEuler([0,0,0])
        self.car = p.loadURDF("test_car.urdf", self.startPos, self.startOrientation)
        
        # ターゲットを表示
        targetX, targetY = np.random.permutation(np.arange(10))[0:2]
        self.targetPos = [targetX, targetY, 0]
        self.target = p.createCollisionShape(
            p.GEOM_CYLINDER, radius=0.2, height=2, collisionFramePosition=self.targetPos)
        p.createMultiBody(0, self.target)

        # 目標の面積, 重心の位置を取得する
        frame = self.renderPicture()
        _, area_sum = self.calc_area(frame)
        area_v = 0

        observation = (area_sum, area_v)
        
        return observation, frame

    def get_env(self, area_sum_before):
        '''環境を認識する'''
        '''カメラで写真をとりOpencv2で面積と重心を取得する'''
        frame = self.renderPicture()
        # 赤色の面積とその変化量, 重心の位置とその変化量を取得する
        _, area_sum = self.calc_area(frame)
        area_v = area_sum - area_sum_before
        # 観測量として返す
        observation = (area_sum, area_v)
        return observation, frame

    def act_env(self, observation, action):
        '''決定したactionに従って、ロボットハンドを動かす'''
        if action == 0:  # 前
            self.go()
        elif action == 1:  # 後
            self.back()
        elif action == 2:  # 右
            self.right()
        elif action == 3:  # 左
            self.left()
        
        for i in range(50):
            p.stepSimulation()
            time.sleep(1./240.)
        
        area_sum, _ = observation
        observation_next, _ = self.get_env(area_sum)
        done = self.is_done(observation_next)
        
        return observation_next, done

    def go(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[20,20,20,20],
                forces=np.ones(4)*self.maxForce)
    def back(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[-20,-20,-20,-20],
                forces=np.ones(4)*self.maxForce)
    def right(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[20,12,20,12],
                forces=np.ones(4)*self.maxForce)
    def left(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[12,20,12,20],
                forces=np.ones(4)*self.maxForce)
    def stop(self):
        p.setJointMotorControlArray(
                self.car, np.arange(p.getNumJoints(self.car))[1:], p.VELOCITY_CONTROL, 
                targetVelocities=[0,0,0,0],
                forces=np.ones(4)*self.maxForce)
    
    def is_done(self, observation):
        '''observationによって終了判定をする'''
        #終了判定は面積が閾値以上&面積の変化なし（重心位置が画像の真ん中？カメラの位置によるけど，とりあえずはなし）
        done = False
        area_sum, area_v = observation
        if area_sum > AREA_THRESH:
            done = True
        return done

    def run(self):
        '''実行'''
        print('Environment.run')
        complete_episodes = 0  # 連続で取り続けた試行数
        is_episode_final = False  # 最終試行フラグ

        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation, frame = self.reset()  # 環境の初期化

            for step in range(MAX_STEPS):  # 1エピソードのループ
                print('Step: {0} of Episode: {1}'.format(step+1, episode))
                # 行動を求める
                action = self.agent.get_action(observation, episode)
                # 行動a_tの実行により、s_{t+1}, r_{t+1}を求める
                observation_next, done = self.act_env(observation, action)

                # 報酬を与える
                if done:
                    reward = 1  # 目標を掴んだら報酬1を与える
                    print ('reward: +1')
                    complete_episodes += 1  # 連続記録を更新
                else:
                    reward = 0  # 途中の報酬は0
                    print ('reward: 0')

                # step+1の状態observation_nextを用いて,Q関数を更新する
                if TEST_MODE:  # 保存したQ-TABLEを使用する
                    continue
                else:
                    self.agent.update_Q_function(observation, action, reward, observation_next)

                # 観測の更新
                observation = observation_next

                # 終了時の処理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(episode, step + 1))
                    break

                # 1episode内でdoneできなかったら罰を与える
                if step == MAX_STEPS-1:
                    reward = -1
                    print('reward: -1')
                    complete_episodes = 0  # 4step以上連続で立ち続けた試行数をリセット

            if is_episode_final is True:  # 最終試行では動画を保存と描画
                Brain(num_states=self.num_states, num_actions=self.num_actions).save_Q_table()  # Q-tableを保存する
                print('finished')
                break

            if complete_episodes >= 10:  # 5連続成功なら
                print('10回連続成功\n次で最終試行')
                is_episode_final = True  # 次の試行を最終試行とする

# %%
robot_hand_env = Environment()
robot_hand_env.run()
# Out:
# Environment.run
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 0
# GREEN_AREA:  4.057
# reward: 0
# Step: 6 of Episode: 0
# GREEN_AREA:  16.679
# reward: 0
# Step: 7 of Episode: 0
# GREEN_AREA:  6.46
# reward: 0
# Step: 8 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 0
# GREEN_AREA:  3.454
# reward: 0
# Step: 11 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 0
# GREEN_AREA:  2.424
# reward: 0
# Step: 14 of Episode: 0
# GREEN_AREA:  2.652
# reward: 0
# Step: 15 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 0
# GREEN_AREA:  4.184
# reward: 0
# Step: 22 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 0
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 0
# GREEN_AREA:  2.832
# reward: 0
# Step: 25 of Episode: 0
# GREEN_AREA:  12.831
# reward: 0
# Step: 26 of Episode: 0
# GREEN_AREA:  18.155
# reward: 0
# Step: 27 of Episode: 0
# GREEN_AREA:  15.146
# reward: 0
# Step: 28 of Episode: 0
# GREEN_AREA:  7.892
# reward: 0
# Step: 29 of Episode: 0
# GREEN_AREA:  11.684
# reward: 0
# Step: 30 of Episode: 0
# GREEN_AREA:  3.165
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  29.046
# Step: 1 of Episode: 1
# GREEN_AREA:  30.777
# reward: 0
# Step: 2 of Episode: 1
# GREEN_AREA:  58.484
# reward: 0
# Step: 3 of Episode: 1
# GREEN_AREA:  45.27
# reward: 0
# Step: 4 of Episode: 1
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 1
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 1
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 1
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 1
# GREEN_AREA:  100.0
# reward: +1
# 1 Episode: Finished after 8 time steps
# Environment.reset
#
# GREEN_AREA:  2.101
# Step: 1 of Episode: 2
# GREEN_AREA:  2.219
# reward: 0
# Step: 2 of Episode: 2
# GREEN_AREA:  2.676
# reward: 0
# Step: 3 of Episode: 2
# GREEN_AREA:  3.528
# reward: 0
# Step: 4 of Episode: 2
# GREEN_AREA:  4.861
# reward: 0
# Step: 5 of Episode: 2
# GREEN_AREA:  7.16
# reward: 0
# Step: 6 of Episode: 2
# GREEN_AREA:  6.677
# reward: 0
# Step: 7 of Episode: 2
# GREEN_AREA:  2.636
# reward: 0
# Step: 8 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 2
# GREEN_AREA:  5.314
# reward: 0
# Step: 13 of Episode: 2
# GREEN_AREA:  5.923
# reward: 0
# Step: 14 of Episode: 2
# GREEN_AREA:  0.746
# reward: 0
# Step: 15 of Episode: 2
# GREEN_AREA:  0.486
# reward: 0
# Step: 16 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 2
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 2
# GREEN_AREA:  1.801
# reward: 0
# Step: 20 of Episode: 2
# GREEN_AREA:  2.184
# reward: 0
# Step: 21 of Episode: 2
# GREEN_AREA:  2.214
# reward: 0
# Step: 22 of Episode: 2
# GREEN_AREA:  2.23
# reward: 0
# Step: 23 of Episode: 2
# GREEN_AREA:  2.231
# reward: 0
# Step: 24 of Episode: 2
# GREEN_AREA:  2.213
# reward: 0
# Step: 25 of Episode: 2
# GREEN_AREA:  2.253
# reward: 0
# Step: 26 of Episode: 2
# GREEN_AREA:  2.27
# reward: 0
# Step: 27 of Episode: 2
# GREEN_AREA:  2.307
# reward: 0
# Step: 28 of Episode: 2
# GREEN_AREA:  2.273
# reward: 0
# Step: 29 of Episode: 2
# GREEN_AREA:  2.262
# reward: 0
# Step: 30 of Episode: 2
# GREEN_AREA:  2.276
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 3
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 3
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 3
# GREEN_AREA:  6.05
# reward: 0
# Step: 4 of Episode: 3
# GREEN_AREA:  6.714
# reward: 0
# Step: 5 of Episode: 3
# GREEN_AREA:  12.756
# reward: 0
# Step: 6 of Episode: 3
# GREEN_AREA:  18.236
# reward: 0
# Step: 7 of Episode: 3
# GREEN_AREA:  15.804
# reward: 0
# Step: 8 of Episode: 3
# GREEN_AREA:  15.43
# reward: 0
# Step: 9 of Episode: 3
# GREEN_AREA:  15.431
# reward: 0
# Step: 10 of Episode: 3
# GREEN_AREA:  13.201
# reward: 0
# Step: 11 of Episode: 3
# GREEN_AREA:  12.797
# reward: 0
# Step: 12 of Episode: 3
# GREEN_AREA:  12.709
# reward: 0
# Step: 13 of Episode: 3
# GREEN_AREA:  12.802
# reward: 0
# Step: 14 of Episode: 3
# GREEN_AREA:  10.726
# reward: 0
# Step: 15 of Episode: 3
# GREEN_AREA:  10.404
# reward: 0
# Step: 16 of Episode: 3
# GREEN_AREA:  10.411
# reward: 0
# Step: 17 of Episode: 3
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 3
# GREEN_AREA:  2.124
# reward: 0
# Step: 19 of Episode: 3
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 3
# GREEN_AREA:  0.001
# reward: 0
# Step: 21 of Episode: 3
# GREEN_AREA:  6.415
# reward: 0
# Step: 22 of Episode: 3
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 3
# GREEN_AREA:  0.037
# reward: 0
# Step: 24 of Episode: 3
# GREEN_AREA:  0.038
# reward: 0
# Step: 25 of Episode: 3
# GREEN_AREA:  0.037
# reward: 0
# Step: 26 of Episode: 3
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 3
# GREEN_AREA:  11.719
# reward: 0
# Step: 28 of Episode: 3
# GREEN_AREA:  16.91
# reward: 0
# Step: 29 of Episode: 3
# GREEN_AREA:  15.013
# reward: 0
# Step: 30 of Episode: 3
# GREEN_AREA:  14.128
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 4
# GREEN_AREA:  4.952
# reward: 0
# Step: 7 of Episode: 4
# GREEN_AREA:  1.789
# reward: 0
# Step: 8 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 4
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 4
# GREEN_AREA:  0.039
# reward: 0
# Step: 12 of Episode: 4
# GREEN_AREA:  8.29
# reward: 0
# Step: 13 of Episode: 4
# GREEN_AREA:  9.141
# reward: 0
# Step: 14 of Episode: 4
# GREEN_AREA:  17.968
# reward: 0
# Step: 15 of Episode: 4
# GREEN_AREA:  9.135
# reward: 0
# Step: 16 of Episode: 4
# GREEN_AREA:  18.768
# reward: 0
# Step: 17 of Episode: 4
# GREEN_AREA:  9.866
# reward: 0
# Step: 18 of Episode: 4
# GREEN_AREA:  18.543
# reward: 0
# Step: 19 of Episode: 4
# GREEN_AREA:  11.996
# reward: 0
# Step: 20 of Episode: 4
# GREEN_AREA:  10.886
# reward: 0
# Step: 21 of Episode: 4
# GREEN_AREA:  10.83
# reward: 0
# Step: 22 of Episode: 4
# GREEN_AREA:  10.812
# reward: 0
# Step: 23 of Episode: 4
# GREEN_AREA:  10.865
# reward: 0
# Step: 24 of Episode: 4
# GREEN_AREA:  18.573
# reward: 0
# Step: 25 of Episode: 4
# GREEN_AREA:  11.062
# reward: 0
# Step: 26 of Episode: 4
# GREEN_AREA:  18.488
# reward: 0
# Step: 27 of Episode: 4
# GREEN_AREA:  16.371
# reward: 0
# Step: 28 of Episode: 4
# GREEN_AREA:  15.894
# reward: 0
# Step: 29 of Episode: 4
# GREEN_AREA:  15.681
# reward: 0
# Step: 30 of Episode: 4
# GREEN_AREA:  15.725
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  1.37
# Step: 1 of Episode: 5
# GREEN_AREA:  1.451
# reward: 0
# Step: 2 of Episode: 5
# GREEN_AREA:  1.688
# reward: 0
# Step: 3 of Episode: 5
# GREEN_AREA:  2.141
# reward: 0
# Step: 4 of Episode: 5
# GREEN_AREA:  1.92
# reward: 0
# Step: 5 of Episode: 5
# GREEN_AREA:  0.674
# reward: 0
# Step: 6 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 5
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 6
# GREEN_AREA:  10.607
# reward: 0
# Step: 7 of Episode: 6
# GREEN_AREA:  2.793
# reward: 0
# Step: 8 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 6
# GREEN_AREA:  0.246
# reward: 0
# Step: 13 of Episode: 6
# GREEN_AREA:  14.075
# reward: 0
# Step: 14 of Episode: 6
# GREEN_AREA:  4.26
# reward: 0
# Step: 15 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 6
# GREEN_AREA:  0.368
# reward: 0
# Step: 18 of Episode: 6
# GREEN_AREA:  8.905
# reward: 0
# Step: 19 of Episode: 6
# GREEN_AREA:  1.171
# reward: 0
# Step: 20 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 6
# GREEN_AREA:  0.708
# reward: 0
# Step: 25 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 6
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 7
# GREEN_AREA:  0.106
# reward: 0
# Step: 18 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 7
# GREEN_AREA:  0.248
# reward: 0
# Step: 27 of Episode: 7
# GREEN_AREA:  11.827
# reward: 0
# Step: 28 of Episode: 7
# GREEN_AREA:  1.866
# reward: 0
# Step: 29 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 7
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 8
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 8
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 8
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 8
# GREEN_AREA:  0.165
# reward: 0
# Step: 10 of Episode: 8
# GREEN_AREA:  7.634
# reward: 0
# Step: 11 of Episode: 8
# GREEN_AREA:  8.093
# reward: 0
# Step: 12 of Episode: 8
# GREEN_AREA:  15.552
# reward: 0
# Step: 13 of Episode: 8
# GREEN_AREA:  7.619
# reward: 0
# Step: 14 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 8
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 8
# GREEN_AREA:  0.558
# reward: 0
# Step: 18 of Episode: 8
# GREEN_AREA:  6.988
# reward: 0
# Step: 19 of Episode: 8
# GREEN_AREA:  8.093
# reward: 0
# Step: 20 of Episode: 8
# GREEN_AREA:  18.006
# reward: 0
# Step: 21 of Episode: 8
# GREEN_AREA:  8.974
# reward: 0
# Step: 22 of Episode: 8
# GREEN_AREA:  18.716
# reward: 0
# Step: 23 of Episode: 8
# GREEN_AREA:  18.617
# reward: 0
# Step: 24 of Episode: 8
# GREEN_AREA:  18.69
# reward: 0
# Step: 25 of Episode: 8
# GREEN_AREA:  17.982
# reward: 0
# Step: 26 of Episode: 8
# GREEN_AREA:  18.006
# reward: 0
# Step: 27 of Episode: 8
# GREEN_AREA:  15.688
# reward: 0
# Step: 28 of Episode: 8
# GREEN_AREA:  15.202
# reward: 0
# Step: 29 of Episode: 8
# GREEN_AREA:  15.219
# reward: 0
# Step: 30 of Episode: 8
# GREEN_AREA:  12.541
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 9
# GREEN_AREA:  4.539
# reward: 0
# Step: 5 of Episode: 9
# GREEN_AREA:  2.588
# reward: 0
# Step: 6 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 9
# GREEN_AREA:  5.953
# reward: 0
# Step: 11 of Episode: 9
# GREEN_AREA:  6.444
# reward: 0
# Step: 12 of Episode: 9
# GREEN_AREA:  2.189
# reward: 0
# Step: 13 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 9
# GREEN_AREA:  3.634
# reward: 0
# Step: 17 of Episode: 9
# GREEN_AREA:  2.021
# reward: 0
# Step: 18 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 9
# GREEN_AREA:  1.617
# reward: 0
# Step: 22 of Episode: 9
# GREEN_AREA:  11.568
# reward: 0
# Step: 23 of Episode: 9
# GREEN_AREA:  2.935
# reward: 0
# Step: 24 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 9
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 9
# GREEN_AREA:  6.783
# reward: 0
# Step: 29 of Episode: 9
# GREEN_AREA:  7.409
# reward: 0
# Step: 30 of Episode: 9
# GREEN_AREA:  11.721
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.639
# Step: 1 of Episode: 10
# GREEN_AREA:  0.646
# reward: 0
# Step: 2 of Episode: 10
# GREEN_AREA:  0.656
# reward: 0
# Step: 3 of Episode: 10
# GREEN_AREA:  0.714
# reward: 0
# Step: 4 of Episode: 10
# GREEN_AREA:  0.729
# reward: 0
# Step: 5 of Episode: 10
# GREEN_AREA:  0.785
# reward: 0
# Step: 6 of Episode: 10
# GREEN_AREA:  0.79
# reward: 0
# Step: 7 of Episode: 10
# GREEN_AREA:  0.795
# reward: 0
# Step: 8 of Episode: 10
# GREEN_AREA:  0.954
# reward: 0
# Step: 9 of Episode: 10
# GREEN_AREA:  0.765
# reward: 0
# Step: 10 of Episode: 10
# GREEN_AREA:  1.684
# reward: 0
# Step: 11 of Episode: 10
# GREEN_AREA:  2.273
# reward: 0
# Step: 12 of Episode: 10
# GREEN_AREA:  2.41
# reward: 0
# Step: 13 of Episode: 10
# GREEN_AREA:  2.659
# reward: 0
# Step: 14 of Episode: 10
# GREEN_AREA:  2.997
# reward: 0
# Step: 15 of Episode: 10
# GREEN_AREA:  3.312
# reward: 0
# Step: 16 of Episode: 10
# GREEN_AREA:  3.883
# reward: 0
# Step: 17 of Episode: 10
# GREEN_AREA:  4.565
# reward: 0
# Step: 18 of Episode: 10
# GREEN_AREA:  5.803
# reward: 0
# Step: 19 of Episode: 10
# GREEN_AREA:  6.251
# reward: 0
# Step: 20 of Episode: 10
# GREEN_AREA:  9.11
# reward: 0
# Step: 21 of Episode: 10
# GREEN_AREA:  13.538
# reward: 0
# Step: 22 of Episode: 10
# GREEN_AREA:  23.9
# reward: 0
# Step: 23 of Episode: 10
# GREEN_AREA:  25.68
# reward: 0
# Step: 24 of Episode: 10
# GREEN_AREA:  23.561
# reward: 0
# Step: 25 of Episode: 10
# GREEN_AREA:  5.614
# reward: 0
# Step: 26 of Episode: 10
# GREEN_AREA:  17.024
# reward: 0
# Step: 27 of Episode: 10
# GREEN_AREA:  5.411
# reward: 0
# Step: 28 of Episode: 10
# GREEN_AREA:  15.382
# reward: 0
# Step: 29 of Episode: 10
# GREEN_AREA:  4.967
# reward: 0
# Step: 30 of Episode: 10
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 11
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 11
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 11
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 11
# GREEN_AREA:  0.151
# reward: 0
# Step: 10 of Episode: 11
# GREEN_AREA:  7.468
# reward: 0
# Step: 11 of Episode: 11
# GREEN_AREA:  18.692
# reward: 0
# Step: 12 of Episode: 11
# GREEN_AREA:  7.609
# reward: 0
# Step: 13 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 11
# GREEN_AREA:  2.154
# reward: 0
# Step: 18 of Episode: 11
# GREEN_AREA:  2.776
# reward: 0
# Step: 19 of Episode: 11
# GREEN_AREA:  2.776
# reward: 0
# Step: 20 of Episode: 11
# GREEN_AREA:  2.761
# reward: 0
# Step: 21 of Episode: 11
# GREEN_AREA:  2.742
# reward: 0
# Step: 22 of Episode: 11
# GREEN_AREA:  2.782
# reward: 0
# Step: 23 of Episode: 11
# GREEN_AREA:  2.761
# reward: 0
# Step: 24 of Episode: 11
# GREEN_AREA:  2.742
# reward: 0
# Step: 25 of Episode: 11
# GREEN_AREA:  2.759
# reward: 0
# Step: 26 of Episode: 11
# GREEN_AREA:  2.741
# reward: 0
# Step: 27 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 11
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.522
# Step: 1 of Episode: 12
# GREEN_AREA:  0.524
# reward: 0
# Step: 2 of Episode: 12
# GREEN_AREA:  0.591
# reward: 0
# Step: 3 of Episode: 12
# GREEN_AREA:  0.646
# reward: 0
# Step: 4 of Episode: 12
# GREEN_AREA:  0.717
# reward: 0
# Step: 5 of Episode: 12
# GREEN_AREA:  7.395
# reward: 0
# Step: 6 of Episode: 12
# GREEN_AREA:  7.999
# reward: 0
# Step: 7 of Episode: 12
# GREEN_AREA:  19.858
# reward: 0
# Step: 8 of Episode: 12
# GREEN_AREA:  14.966
# reward: 0
# Step: 9 of Episode: 12
# GREEN_AREA:  14.396
# reward: 0
# Step: 10 of Episode: 12
# GREEN_AREA:  13.952
# reward: 0
# Step: 11 of Episode: 12
# GREEN_AREA:  13.382
# reward: 0
# Step: 12 of Episode: 12
# GREEN_AREA:  13.172
# reward: 0
# Step: 13 of Episode: 12
# GREEN_AREA:  13.213
# reward: 0
# Step: 14 of Episode: 12
# GREEN_AREA:  18.19
# reward: 0
# Step: 15 of Episode: 12
# GREEN_AREA:  14.803
# reward: 0
# Step: 16 of Episode: 12
# GREEN_AREA:  14.002
# reward: 0
# Step: 17 of Episode: 12
# GREEN_AREA:  14.077
# reward: 0
# Step: 18 of Episode: 12
# GREEN_AREA:  10.514
# reward: 0
# Step: 19 of Episode: 12
# GREEN_AREA:  9.629
# reward: 0
# Step: 20 of Episode: 12
# GREEN_AREA:  9.417
# reward: 0
# Step: 21 of Episode: 12
# GREEN_AREA:  9.595
# reward: 0
# Step: 22 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 12
# GREEN_AREA:  2.46
# reward: 0
# Step: 24 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 12
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 13
# GREEN_AREA:  4.211
# reward: 0
# Step: 8 of Episode: 13
# GREEN_AREA:  4.432
# reward: 0
# Step: 9 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 13
# GREEN_AREA:  0.894
# reward: 0
# Step: 12 of Episode: 13
# GREEN_AREA:  9.444
# reward: 0
# Step: 13 of Episode: 13
# GREEN_AREA:  2.884
# reward: 0
# Step: 14 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 13
# GREEN_AREA:  0.903
# reward: 0
# Step: 18 of Episode: 13
# GREEN_AREA:  9.474
# reward: 0
# Step: 19 of Episode: 13
# GREEN_AREA:  1.832
# reward: 0
# Step: 20 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 13
# GREEN_AREA:  0.84
# reward: 0
# Step: 24 of Episode: 13
# GREEN_AREA:  5.982
# reward: 0
# Step: 25 of Episode: 13
# GREEN_AREA:  6.49
# reward: 0
# Step: 26 of Episode: 13
# GREEN_AREA:  1.229
# reward: 0
# Step: 27 of Episode: 13
# GREEN_AREA:  0.688
# reward: 0
# Step: 28 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 13
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 14
# GREEN_AREA:  0.799
# reward: 0
# Step: 4 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 6 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 14
# GREEN_AREA:  4.007
# reward: 0
# Step: 8 of Episode: 14
# GREEN_AREA:  1.643
# reward: 0
# Step: 9 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 14
# GREEN_AREA:  1.169
# reward: 0
# Step: 14 of Episode: 14
# GREEN_AREA:  11.153
# reward: 0
# Step: 15 of Episode: 14
# GREEN_AREA:  3.521
# reward: 0
# Step: 16 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 14
# GREEN_AREA:  0.828
# reward: 0
# Step: 20 of Episode: 14
# GREEN_AREA:  9.537
# reward: 0
# Step: 21 of Episode: 14
# GREEN_AREA:  2.616
# reward: 0
# Step: 22 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 14
# GREEN_AREA:  0.882
# reward: 0
# Step: 26 of Episode: 14
# GREEN_AREA:  10.429
# reward: 0
# Step: 27 of Episode: 14
# GREEN_AREA:  1.625
# reward: 0
# Step: 28 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 14
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 15
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 15
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 15
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 15
# GREEN_AREA:  0.151
# reward: 0
# Step: 10 of Episode: 15
# GREEN_AREA:  0.392
# reward: 0
# Step: 11 of Episode: 15
# GREEN_AREA:  5.151
# reward: 0
# Step: 12 of Episode: 15
# GREEN_AREA:  5.359
# reward: 0
# Step: 13 of Episode: 15
# GREEN_AREA:  0.617
# reward: 0
# Step: 14 of Episode: 15
# GREEN_AREA:  0.354
# reward: 0
# Step: 15 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 15
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 15
# GREEN_AREA:  1.895
# reward: 0
# Step: 19 of Episode: 15
# GREEN_AREA:  2.448
# reward: 0
# Step: 20 of Episode: 15
# GREEN_AREA:  2.418
# reward: 0
# Step: 21 of Episode: 15
# GREEN_AREA:  2.431
# reward: 0
# Step: 22 of Episode: 15
# GREEN_AREA:  2.475
# reward: 0
# Step: 23 of Episode: 15
# GREEN_AREA:  2.453
# reward: 0
# Step: 24 of Episode: 15
# GREEN_AREA:  2.45
# reward: 0
# Step: 25 of Episode: 15
# GREEN_AREA:  2.453
# reward: 0
# Step: 26 of Episode: 15
# GREEN_AREA:  2.496
# reward: 0
# Step: 27 of Episode: 15
# GREEN_AREA:  2.46
# reward: 0
# Step: 28 of Episode: 15
# GREEN_AREA:  2.452
# reward: 0
# Step: 29 of Episode: 15
# GREEN_AREA:  2.421
# reward: 0
# Step: 30 of Episode: 15
# GREEN_AREA:  2.47
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  1.26
# Step: 1 of Episode: 16
# GREEN_AREA:  1.338
# reward: 0
# Step: 2 of Episode: 16
# GREEN_AREA:  1.487
# reward: 0
# Step: 3 of Episode: 16
# GREEN_AREA:  7.484
# reward: 0
# Step: 4 of Episode: 16
# GREEN_AREA:  8.387
# reward: 0
# Step: 5 of Episode: 16
# GREEN_AREA:  21.171
# reward: 0
# Step: 6 of Episode: 16
# GREEN_AREA:  15.998
# reward: 0
# Step: 7 of Episode: 16
# GREEN_AREA:  16.441
# reward: 0
# Step: 8 of Episode: 16
# GREEN_AREA:  24.18
# reward: 0
# Step: 9 of Episode: 16
# GREEN_AREA:  27.328
# reward: 0
# Step: 10 of Episode: 16
# GREEN_AREA:  25.624
# reward: 0
# Step: 11 of Episode: 16
# GREEN_AREA:  28.479
# reward: 0
# Step: 12 of Episode: 16
# GREEN_AREA:  14.589
# reward: 0
# Step: 13 of Episode: 16
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 16
# GREEN_AREA:  0.847
# reward: 0
# Step: 15 of Episode: 16
# GREEN_AREA:  0.712
# reward: 0
# Step: 16 of Episode: 16
# GREEN_AREA:  0.406
# reward: 0
# Step: 17 of Episode: 16
# GREEN_AREA:  0.47
# reward: 0
# Step: 18 of Episode: 16
# GREEN_AREA:  0.004
# reward: 0
# Step: 19 of Episode: 16
# GREEN_AREA:  0.158
# reward: 0
# Step: 20 of Episode: 16
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 16
# GREEN_AREA:  0.655
# reward: 0
# Step: 22 of Episode: 16
# GREEN_AREA:  0.133
# reward: 0
# Step: 23 of Episode: 16
# GREEN_AREA:  0.44
# reward: 0
# Step: 24 of Episode: 16
# GREEN_AREA:  0.655
# reward: 0
# Step: 25 of Episode: 16
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 16
# GREEN_AREA:  0.248
# reward: 0
# Step: 27 of Episode: 16
# GREEN_AREA:  1.221
# reward: 0
# Step: 28 of Episode: 16
# GREEN_AREA:  1.33
# reward: 0
# Step: 29 of Episode: 16
# GREEN_AREA:  0.73
# reward: 0
# Step: 30 of Episode: 16
# GREEN_AREA:  0.4
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 4 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 5 of Episode: 17
# GREEN_AREA:  0.92
# reward: 0
# Step: 6 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 11 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 12 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 13 of Episode: 17
# GREEN_AREA:  15.158
# reward: 0
# Step: 14 of Episode: 17
# GREEN_AREA:  7.309
# reward: 0
# Step: 15 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 17
# GREEN_AREA:  9.944
# reward: 0
# Step: 18 of Episode: 17
# GREEN_AREA:  1.669
# reward: 0
# Step: 19 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 22 of Episode: 17
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 17
# GREEN_AREA:  6.584
# reward: 0
# Step: 24 of Episode: 17
# GREEN_AREA:  7.264
# reward: 0
# Step: 25 of Episode: 17
# GREEN_AREA:  18.619
# reward: 0
# Step: 26 of Episode: 17
# GREEN_AREA:  9.796
# reward: 0
# Step: 27 of Episode: 17
# GREEN_AREA:  18.47
# reward: 0
# Step: 28 of Episode: 17
# GREEN_AREA:  14.237
# reward: 0
# Step: 29 of Episode: 17
# GREEN_AREA:  12.946
# reward: 0
# Step: 30 of Episode: 17
# GREEN_AREA:  12.951
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 18
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 18
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 18
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 18
# GREEN_AREA:  0.151
# reward: 0
# Step: 10 of Episode: 18
# GREEN_AREA:  7.468
# reward: 0
# Step: 11 of Episode: 18
# GREEN_AREA:  7.979
# reward: 0
# Step: 12 of Episode: 18
# GREEN_AREA:  14.118
# reward: 0
# Step: 13 of Episode: 18
# GREEN_AREA:  18.095
# reward: 0
# Step: 14 of Episode: 18
# GREEN_AREA:  15.202
# reward: 0
# Step: 15 of Episode: 18
# GREEN_AREA:  14.588
# reward: 0
# Step: 16 of Episode: 18
# GREEN_AREA:  14.6
# reward: 0
# Step: 17 of Episode: 18
# GREEN_AREA:  11.933
# reward: 0
# Step: 18 of Episode: 18
# GREEN_AREA:  14.178
# reward: 0
# Step: 19 of Episode: 18
# GREEN_AREA:  10.886
# reward: 0
# Step: 20 of Episode: 18
# GREEN_AREA:  9.784
# reward: 0
# Step: 21 of Episode: 18
# GREEN_AREA:  9.709
# reward: 0
# Step: 22 of Episode: 18
# GREEN_AREA:  9.706
# reward: 0
# Step: 23 of Episode: 18
# GREEN_AREA:  9.778
# reward: 0
# Step: 24 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 18
# GREEN_AREA:  2.339
# reward: 0
# Step: 26 of Episode: 18
# GREEN_AREA:  0.05
# reward: 0
# Step: 27 of Episode: 18
# GREEN_AREA:  3.429
# reward: 0
# Step: 28 of Episode: 18
# GREEN_AREA:  17.33
# reward: 0
# Step: 29 of Episode: 18
# GREEN_AREA:  3.761
# reward: 0
# Step: 30 of Episode: 18
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 19
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 19
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 19
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 19
# GREEN_AREA:  1.893
# reward: 0
# Step: 7 of Episode: 19
# GREEN_AREA:  1.893
# reward: 0
# Step: 8 of Episode: 19
# GREEN_AREA:  1.848
# reward: 0
# Step: 9 of Episode: 19
# GREEN_AREA:  1.855
# reward: 0
# Step: 10 of Episode: 19
# GREEN_AREA:  1.794
# reward: 0
# Step: 11 of Episode: 19
# GREEN_AREA:  1.818
# reward: 0
# Step: 12 of Episode: 19
# GREEN_AREA:  1.794
# reward: 0
# Step: 13 of Episode: 19
# GREEN_AREA:  1.815
# reward: 0
# Step: 14 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 19
# GREEN_AREA:  2.785
# reward: 0
# Step: 18 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 19
# GREEN_AREA:  2.707
# reward: 0
# Step: 22 of Episode: 19
# GREEN_AREA:  3.151
# reward: 0
# Step: 23 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 19
# GREEN_AREA:  5.825
# reward: 0
# Step: 27 of Episode: 19
# GREEN_AREA:  6.452
# reward: 0
# Step: 28 of Episode: 19
# GREEN_AREA:  0.738
# reward: 0
# Step: 29 of Episode: 19
# GREEN_AREA:  0.38
# reward: 0
# Step: 30 of Episode: 19
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 20
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 20
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 20
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 20
# GREEN_AREA:  5.817
# reward: 0
# Step: 11 of Episode: 20
# GREEN_AREA:  6.348
# reward: 0
# Step: 12 of Episode: 20
# GREEN_AREA:  0.867
# reward: 0
# Step: 13 of Episode: 20
# GREEN_AREA:  0.496
# reward: 0
# Step: 14 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 20
# GREEN_AREA:  0.346
# reward: 0
# Step: 21 of Episode: 20
# GREEN_AREA:  3.24
# reward: 0
# Step: 22 of Episode: 20
# GREEN_AREA:  3.223
# reward: 0
# Step: 23 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 20
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 20
# GREEN_AREA:  11.048
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 21
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 21
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 21
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 10 of Episode: 21
# GREEN_AREA:  5.817
# reward: 0
# Step: 11 of Episode: 21
# GREEN_AREA:  6.348
# reward: 0
# Step: 12 of Episode: 21
# GREEN_AREA:  0.867
# reward: 0
# Step: 13 of Episode: 21
# GREEN_AREA:  0.496
# reward: 0
# Step: 14 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 15 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 17 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 18 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 19 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 20 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 21 of Episode: 21
# GREEN_AREA:  0.965
# reward: 0
# Step: 22 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 24 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 25 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 26 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 27 of Episode: 21
# GREEN_AREA:  1.991
# reward: 0
# Step: 28 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 29 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# Step: 30 of Episode: 21
# GREEN_AREA:  0.0
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  2.031
# Step: 1 of Episode: 22
# GREEN_AREA:  2.203
# reward: 0
# Step: 2 of Episode: 22
# GREEN_AREA:  2.473
# reward: 0
# Step: 3 of Episode: 22
# GREEN_AREA:  3.008
# reward: 0
# Step: 4 of Episode: 22
# GREEN_AREA:  3.96
# reward: 0
# Step: 5 of Episode: 22
# GREEN_AREA:  5.654
# reward: 0
# Step: 6 of Episode: 22
# GREEN_AREA:  8.068
# reward: 0
# Step: 7 of Episode: 22
# GREEN_AREA:  12.552
# reward: 0
# Step: 8 of Episode: 22
# GREEN_AREA:  17.121
# reward: 0
# Step: 9 of Episode: 22
# GREEN_AREA:  25.791
# reward: 0
# Step: 10 of Episode: 22
# GREEN_AREA:  29.97
# reward: 0
# Step: 11 of Episode: 22
# GREEN_AREA:  22.277
# reward: 0
# Step: 12 of Episode: 22
# GREEN_AREA:  15.789
# reward: 0
# Step: 13 of Episode: 22
# GREEN_AREA:  0.0
# reward: 0
# Step: 14 of Episode: 22
# GREEN_AREA:  1.966
# reward: 0
# Step: 15 of Episode: 22
# GREEN_AREA:  0.0
# reward: 0
# Step: 16 of Episode: 22
# GREEN_AREA:  2.008
# reward: 0
# Step: 17 of Episode: 22
# GREEN_AREA:  74.744
# reward: 0
# Step: 18 of Episode: 22
# GREEN_AREA:  29.119
# reward: 0
# Step: 19 of Episode: 22
# GREEN_AREA:  2.012
# reward: 0
# Step: 20 of Episode: 22
# GREEN_AREA:  0.915
# reward: 0
# Step: 21 of Episode: 22
# GREEN_AREA:  1.139
# reward: 0
# Step: 22 of Episode: 22
# GREEN_AREA:  0.0
# reward: 0
# Step: 23 of Episode: 22
# GREEN_AREA:  0.021
# reward: 0
# Step: 24 of Episode: 22
# GREEN_AREA:  0.011
# reward: 0
# Step: 25 of Episode: 22
# GREEN_AREA:  0.038
# reward: 0
# Step: 26 of Episode: 22
# GREEN_AREA:  0.033
# reward: 0
# Step: 27 of Episode: 22
# GREEN_AREA:  0.0
# reward: 0
# Step: 28 of Episode: 22
# GREEN_AREA:  0.027
# reward: 0
# Step: 29 of Episode: 22
# GREEN_AREA:  0.032
# reward: 0
# Step: 30 of Episode: 22
# GREEN_AREA:  0.039
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.363
# Step: 1 of Episode: 23
# GREEN_AREA:  0.375
# reward: 0
# Step: 2 of Episode: 23
# GREEN_AREA:  0.419
# reward: 0
# Step: 3 of Episode: 23
# GREEN_AREA:  0.455
# reward: 0
# Step: 4 of Episode: 23
# GREEN_AREA:  0.477
# reward: 0
# Step: 5 of Episode: 23
# GREEN_AREA:  4.551
# reward: 0
# Step: 6 of Episode: 23
# GREEN_AREA:  3.049
# reward: 0
# Step: 7 of Episode: 23
# GREEN_AREA:  0.569
# reward: 0
# Step: 8 of Episode: 23
# GREEN_AREA:  0.625
# reward: 0
# Step: 9 of Episode: 23
# GREEN_AREA:  0.656
# reward: 0
# Step: 10 of Episode: 23
# GREEN_AREA:  2.064
# reward: 0
# Step: 11 of Episode: 23
# GREEN_AREA:  2.604
# reward: 0
# Step: 12 of Episode: 23
# GREEN_AREA:  2.761
# reward: 0
# Step: 13 of Episode: 23
# GREEN_AREA:  2.955
# reward: 0
# Step: 14 of Episode: 23
# GREEN_AREA:  3.189
# reward: 0
# Step: 15 of Episode: 23
# GREEN_AREA:  1.695
# reward: 0
# Step: 16 of Episode: 23
# GREEN_AREA:  2.104
# reward: 0
# Step: 17 of Episode: 23
# GREEN_AREA:  2.631
# reward: 0
# Step: 18 of Episode: 23
# GREEN_AREA:  3.4
# reward: 0
# Step: 19 of Episode: 23
# GREEN_AREA:  4.732
# reward: 0
# Step: 20 of Episode: 23
# GREEN_AREA:  6.676
# reward: 0
# Step: 21 of Episode: 23
# GREEN_AREA:  11.888
# reward: 0
# Step: 22 of Episode: 23
# GREEN_AREA:  26.127
# reward: 0
# Step: 23 of Episode: 23
# GREEN_AREA:  26.073
# reward: 0
# Step: 24 of Episode: 23
# GREEN_AREA:  28.811
# reward: 0
# Step: 25 of Episode: 23
# GREEN_AREA:  13.841
# reward: 0
# Step: 26 of Episode: 23
# GREEN_AREA:  17.813
# reward: 0
# Step: 27 of Episode: 23
# GREEN_AREA:  15.486
# reward: 0
# Step: 28 of Episode: 23
# GREEN_AREA:  15.2
# reward: 0
# Step: 29 of Episode: 23
# GREEN_AREA:  15.205
# reward: 0
# Step: 30 of Episode: 23
# GREEN_AREA:  12.246
# reward: 0
# reward: -1
# Environment.reset
#
# GREEN_AREA:  0.0
# Step: 1 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 2 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 3 of Episode: 24
# GREEN_AREA:  5.765
# reward: 0
# Step: 4 of Episode: 24
# GREEN_AREA:  6.249
# reward: 0
# Step: 5 of Episode: 24
# GREEN_AREA:  2.089
# reward: 0
# Step: 6 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 7 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 8 of Episode: 24
# GREEN_AREA:  0.0
# reward: 0
# Step: 9 of Episode: 24
# GREEN_AREA:  0.151
# reward: 0
# Step: 10 of Episode: 24
# GREEN_AREA:  7.468
# reward: 0
# Step: 11 of Episode: 24
# GREEN_AREA:  7.979
# reward: 0
# Step: 12 of Episode: 24
# GREEN_AREA:  14.118
# reward: 0
# Step: 13 of Episode: 24
# GREEN_AREA:  18.095
# reward: 0
# Step: 14 of Episode: 24
